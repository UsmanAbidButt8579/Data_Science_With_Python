# %% [markdown]
# <h1 style="font-family: 'poppins'; font-weight: bold; color: Green;">👨‍💻Author: Usman Abid Butt</h1>
#
# [![GitHub](https://img.shields.io/badge/GitHub-Profile-blue?style=for-the-badge&logo=github)](https://github.com/UsmanAbidButt8579)
#
# [![Kaggle](https://img.shields.io/badge/Kaggle-Profile-blue?style=for-the-badge&logo=kaggle)](https://www.kaggle.com/usmanabidbutt8579)
#
# [![LinkedIn](https://img.shields.io/badge/LinkedIn-Profile-blue?style=for-the-badge&logo=linkedin)](https://www.linkedin.com/in/usman-abid-butt-85b961186/)
#
# [![Twitter/X](https://img.shields.io/badge/Twitter-Profile-blue?style=for-the-badge&logo=twitter)](https://x.com/UsmanButt851329)
#
# [![Email](https://img.shields.io/badge/Email-Contact%20Me-red?style=for-the-badge&logo=email)](mailto:busmanabid@gmail.com)

# %% [markdown]
# # **Google Play Store Apps**
# **Google Play Store App data of 2.3 Million+ applications.**

# %% [markdown]
# ## About Dataset
#
# >- **`Description`**\
# > The Data Set was downloaded from Kaggle, from the following [link](https://www.kaggle.com/datasets/gauthamp10/google-playstore-apps/data)
#
# - `Context`
# Google PlayStore Android App Data. (2.3 Million+ App Data)
# Backup repo: https://github.com/gauthamp10/Google-Playstore-Dataset
#
# - `Content`
# I've collected the data with the help of Python script (Scrapy) running on a cloud vm instance.
# The data was collected in the month of June 2021.
#
# Also checkout:
#
# * Apple AppStore Apps dataset: https://www.kaggle.com/gauthamp10/apple-appstore-apps
# * Android App Permission dataset: https://www.kaggle.com/gauthamp10/app-permissions-android
#
# - `Acknowledgements`
# I couldn't have build this dataset without the help of Github Education and switched to facundoolano/google-play-scraper for sane reasons.
#
# - `Inspiration`
# Took inspiration from: https://www.kaggle.com/lava18/google-play-store-apps to build a big database for students and researchers!

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv('googleplaystore.csv')

# %%
# Explore the dataset
df.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
# Check for missing values
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
# hide all warnings runtime
import warnings
warnings.filterwarnings('ignore')

# %%
# Handle missing values
df = df.dropna(subset=['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver'])

# %%
df.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
# find the specific column unique values
df['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '5.5M', '17M', '39M', '31M',
#        '4.2M', '23M', '6.0M', '6.1M', '4.6M', '9.2M', '5.2M', '11M',
#        '24M', 'Varies with device', '9.4M', '15M', '10M', '1.2M', '26M',
#        '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k', '3.6M', '5.7M',
#        '8.6M', '2.4M', '27M', '2.7M', '2.5M', '7.0M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '22M', '6.4M', '3.2M', '8.2M', '4.9M', '9.5M', '5.0M',
#        '5.9M', '13M', '73M', '6.8M', '3.5M', '4.0M', '2.3M', '2.1M',
#        '42M', '9.1M', '55M', '23k', '7.3M', '6.5M', '1.5M', '7.5M', '51M',
#        '41M', '48M', '8.5M', '46M', '8.3M', '4.3M', '4.7M', '3.3M', '40M',
#        '7.8M', '8.8M', '6.6M', '5.1M', '61M', '66M', '79k', '8.4M',
# ...

# %%
# find the values in size column which has 'M' in it
df['Size'].loc[df['Size'].str.contains('M')].value_counts().sum()
# Out:
# 7466

# %%
# find the values in size column which has 'k' in it
df['Size'].loc[df['Size'].str.contains('k')].value_counts().sum()
# Out:
# 257

# %%
# find the values in size column which has 'Varies with device' in it
df['Size'].loc[df['Size'].str.contains('Varies with device')].value_counts().sum()
# Out:
# 1637

# %%
# Total Values in Size column
df['Size'].value_counts().sum()
# Out:
# 9360

# %%
# taking sum of all the values in size column which has 'M', 'K' and 'varies with device' in it
8830+316+1695
# Out:
# 10841

# %% [markdown]
# - We have `8830` values in `M` units
# - We have `316` values in `k` units
# - We have `1695` value in `Varies with device`
#
# > Let's convert the `M` and `K` units into bytes and then remove the `M` and `K` from the values and convert them into numeric data type.

# %%
# convert the size column to numeric by multiplying the values with 1024 if it has 'k' in it and 1024*1024 if it has 'M' in it
# this function will convert the size column to numeric
def convert_size(size):
    # add function details here
    '''
    This function will convert the size column to numeric by multiplying the values with 1024 if it has 'k' in it and 1024*1024 if it has 'M' in it
    '''
    
    if isinstance(size, str):
        if 'k' in size:
            return float(size.replace('k', '')) * 1024
        elif 'M' in size:
            return float(size.replace('M', '')) * 1024 * 1024
        elif 'Varies with device' in size:
            return np.nan
    return size

df['Size'] = df['Size'].apply(convert_size)

# %%
# rename the column name 'Size' to 'Size_in_bytes'
df.rename(columns={'Size': 'Size_in_bytes'}, inplace=True)

# %%
# making a new column called 'Size in Mb' which will have the size in MB
df['Size_in_Mb'] = df['Size_in_bytes'].apply(lambda x: x/(1024*1024))

# %% [markdown]
# - Now we have converted every value into bytes and removed the `M` and `K` from the values and converted them into numeric data type.
# - 'Varies with device' was a string value, therefore we intentionally converted them into null values, which we can fill later on according to our needs.
#
# ---
# - Let's have a look on the `Installs` column

# %%
# check the unique values in size column
df['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '100+', '500+', '10+',
#        '5+', '50+', '1+'], dtype=object)

# %%
# let's have a values counts
df['Installs'].value_counts()
# Out:
# Installs
# 1,000,000+        1576
# 10,000,000+       1252
# 100,000+          1150
# 10,000+           1009
# 5,000,000+         752
# 1,000+             712
# 500,000+           537
# 50,000+            466
# 5,000+             431
# 100,000,000+       409
# 100+               309
# 50,000,000+        289
# 500+               201
# 500,000,000+        72
# 10+                 69
# 1,000,000,000+      58
# 50+                 56
# 5+                   9
# 1+                   3
# Name: count, dtype: int64

# %% [markdown]
# - Let's verify if the dtypes has been changes

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size_in_bytes     Installs  Type Price Content Rating  \
# 0     159     19922944.0      10,000+  Free     0       Everyone
# 1     967     14680064.0     500,000+  Free     0       Everyone
# 2   87510      9122611.2   5,000,000+  Free     0       Everyone
# 3  215644     26214400.0  50,000,000+  Free     0           Teen
# 4     967      2936012.8     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# ...

# %% [markdown]
# - Let's have a look on the `Price` column

# %%
# check the unique values in the 'Price' column
df['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$7.99', '$5.99', '$2.99', '$3.49',
#        '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49', '$10.00',
#        '$24.99', '$11.99', '$79.99', '$16.99', '$14.99', '$29.99',
#        '$12.99', '$2.49', '$10.99', '$1.50', '$19.99', '$15.99', '$33.99',
#        '$39.99', '$3.95', '$4.49', '$1.70', '$8.99', '$1.49', '$3.88',
#        '$399.99', '$17.99', '$400.00', '$3.02', '$1.76', '$4.84', '$4.77',
#        '$1.61', '$2.50', '$1.59', '$6.49', '$1.29', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$8.49', '$1.75', '$14.00', '$2.00',
#        '$3.08', '$2.59', '$19.40', '$3.90', '$4.59', '$15.46', '$3.04',
#        '$13.99', '$4.29', '$3.28', '$4.60', '$1.00', '$2.95', '$2.90',
#        '$1.97', '$2.56', '$1.20'], dtype=object)

# %%
df['Price'].value_counts() # check the value counts of the 'Price' column
# Out:
# Price
# 0          8715
# $2.99       114
# $0.99       106
# $4.99        70
# $1.99        59
#            ...
# $1.29         1
# $299.99       1
# $379.99       1
# $37.99        1
# $1.20         1
# Name: count, Length: 73, dtype: int64

# %%
# count the values having $ in the 'Price' column
df['Price'].loc[df['Price'].str.contains('\$')].value_counts().sum()
# Out:
# 645

# %%
# remove the dollar sign from the price column and convert it to numeric
df['Price'] = df['Price'].apply(lambda x: x.replace('$', '') if '$' in str(x) else x)
# convert the price column to numeric (float because this is the price)
df['Price'] = df['Price'].apply(lambda x: float(x))

# %%
df['Price'].dtype # this will show the data type of the column
# Out:
# dtype('float64')

# %%
# using f string to print the min, max and average price of the apps
print(f"Min price is: {df['Price'].min()} $")
print(f"Max price is: {df['Price'].max()} $")
print(f"Average price is: {df['Price'].mean()} $")
# Out:
# Min price is: 0.0 $
# Max price is: 400.0 $
# Average price is: 0.9612788461538462 $

# %%
# remove the dublicates from dataset

df = df.drop_duplicates()
df.shape # the shape of the dataframe after removing the duplicates
# Out:
# (8886, 14)

# %%
df.describe() # these are numeric columns
# Out:
#             Rating  Size_in_bytes        Price   Size_in_Mb
# count  8886.000000   7.418000e+03  8886.000000  7418.000000
# mean      4.187959   2.386609e+07     0.963526    22.760481
# std       0.522428   2.457814e+07    16.194792    23.439539
# min       1.000000   8.704000e+03     0.000000     0.008301
# 25%       4.000000   5.347738e+06     0.000000     5.100000
# 50%       4.300000   1.468006e+07     0.000000    14.000000
# 75%       4.500000   3.460301e+07     0.000000    33.000000
# max       5.000000   1.048576e+08   400.000000   100.000000

# %%
# Exploratory Data Analysis
# 1. Analyze the distribution of app ratings
plt.figure(figsize=(8, 6))
sns.histplot(df['Rating'], bins=10)
plt.title('Distribution of App Ratings')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

# %%
# 2. Analyze the distribution of app sizes
plt.figure(figsize=(8, 6))
sns.histplot(df['Size_in_Mb'], bins=10)
plt.title('Distribution of App Sizes')
plt.xlabel('Size')
plt.ylabel('Count')
plt.show()

# %%
# 3. Analyze the distribution of app installs
plt.figure(figsize=(8, 6))
sns.histplot(df['Installs'], bins=10)
plt.title('Distribution of App Installs')
plt.xlabel('Installs')
plt.ylabel('Count')
plt.show()

# %%
# 4. Analyze the distribution of app prices
plt.figure(figsize=(8, 6))
sns.histplot(df['Price'], bins=10)
plt.title('Distribution of App Prices')
plt.xlabel('Price ($)')
plt.ylabel('Count')
plt.show()

# %%
# 5. Analyze the distribution of app categories
plt.figure(figsize=(12, 8))
sns.countplot(x='Category', data=df)
plt.xticks(rotation=90)
plt.title('Distribution of App Categories')
plt.xlabel('Category')
plt.ylabel('Count')
plt.show()

# %%
# 7. Analyze the most popular app genres
plt.figure(figsize=(12, 8))
#df['Genres'] = df['Genres'].str.split(';').explode()
sns.countplot(x='Genres', data=df)
plt.xticks(rotation=90)
plt.title('Most Popular App Genres')
plt.xlabel('Genre')
plt.ylabel('Count')
plt.show()

# %%
# 8. Analyze the distribution of app content ratings
plt.figure(figsize=(8, 6))
sns.countplot(x='Content Rating', data=df)
plt.title('Distribution of App Content Ratings')
plt.xlabel('Content Rating')
plt.ylabel('Count')
plt.show()

# %%
# 9. Analyze the distribution of app version updates
plt.figure(figsize=(12, 8))
df['Last Updated Year'] = df['Last Updated']
sns.countplot(x='Last Updated Year', data=df)
plt.title('Distribution of App Version Updates')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This exploratory data analysis provides a comprehensive overview of the Google Play Store Apps dataset. It includes the following steps:
#
# 1. Import necessary libraries
# 2. Load the dataset
# 3. Explore the dataset (head, info, describe)
# 4. Check for and handle missing values
# 5. Explore the data types and convert to appropriate data types
# 6. Analyze the distribution of app ratings
# 7. Analyze the distribution of app sizes
# 8. Analyze the distribution of app installs
# 9. Analyze the distribution of app prices
# 10. Analyze the distribution of app categories
# 11. Analyze the correlation between app features
# 12. Analyze the most popular app genres
# 13. Analyze the distribution of app content ratings
# 14. Analyze the distribution of app version updates
#
# Each step includes visualizations and explanations to gain insights into the dataset. This provides a solid foundation for further analysis and model development.
