# %% [markdown]
# # pandas tutorial (day-11)
# this notebook explains.....

# %% [markdown]
# - install libraries

# %%
# pip install pandas
# pip install numpy

# %% [markdown]
#   - import libraries

# %%
import pandas as pd
import numpy as np

# %%
# object creation
s=pd.Series([1,2,3,7,np.nan,8,9])
s
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    7.0
# 4    NaN
# 5    8.0
# 6    9.0
# dtype: float64

# %%
dates=pd.date_range("20130101",periods=20)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06', '2013-01-07', '2013-01-08',
#                '2013-01-09', '2013-01-10', '2013-01-11', '2013-01-12',
#                '2013-01-13', '2013-01-14', '2013-01-15', '2013-01-16',
#                '2013-01-17', '2013-01-18', '2013-01-19', '2013-01-20'],
#               dtype='datetime64[ns]', freq='D')

# %%
df=pd.DataFrame(np.random.randn(20,4),index=dates,columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.344061 -0.760255  0.773429  2.057470
# 2013-01-02 -1.223932 -1.057238 -1.138202  0.073090
# 2013-01-03  0.274699 -1.624815 -1.082887  0.593062
# 2013-01-04  0.551384 -0.580066  1.614219 -0.409645
# 2013-01-05  1.257205  0.358768 -2.551062 -1.841047
# 2013-01-06  0.611864 -0.301210 -0.553141  2.282509
# 2013-01-07  2.258037  0.642537 -0.236168 -1.485637
# 2013-01-08 -0.729323 -0.503774 -0.491015 -1.265484
# 2013-01-09  0.992290  0.172734  1.092731 -1.529189
# 2013-01-10 -0.635694  1.000938  0.647804  0.594693
# 2013-01-11 -0.184144  0.283592 -0.881308 -0.245401
# 2013-01-12 -0.610837 -1.551997  2.057645 -0.820753
# 2013-01-13 -0.234148 -0.153085  0.331640  0.582614
# 2013-01-14  2.139897  0.890055 -0.076824  0.020482
# 2013-01-15 -0.100896  1.182679  1.356832  0.219337
# 2013-01-16  0.353042  0.343070  0.863696 -1.367427
# 2013-01-17  0.443104 -0.476834  0.057122  0.345396
# ...

# %%
df2 = pd.DataFrame(
    {
        "A":1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3]*4, dtype="int32"),
        "E":pd.Categorical(["test","train","test","train"]),
        "F": "females",
    }
)    
df2
# Out:
#      A          B    C  D      E        F
# 0  1.0 2013-01-02  1.0  3   test  females
# 1  1.0 2013-01-02  1.0  3  train  females
# 2  1.0 2013-01-02  1.0  3   test  females
# 3  1.0 2013-01-02  1.0  3  train  females

# %%
df.dtypes
# Out:
# A    float64
# B    float64
# C    float64
# D    float64
# dtype: object

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01 -0.344061 -0.760255  0.773429  2.057470
# 2013-01-02 -1.223932 -1.057238 -1.138202  0.073090
# 2013-01-03  0.274699 -1.624815 -1.082887  0.593062
# 2013-01-04  0.551384 -0.580066  1.614219 -0.409645
# 2013-01-05  1.257205  0.358768 -2.551062 -1.841047

# %%
df.head(2)
# Out:
#                    A         B         C        D
# 2013-01-01 -0.344061 -0.760255  0.773429  2.05747
# 2013-01-02 -1.223932 -1.057238 -1.138202  0.07309

# %%
df.tail(2)
# Out:
#                    A         B         C         D
# 2013-01-19 -0.600790  0.654585 -2.499953  0.700256
# 2013-01-20  0.831436 -0.770276 -1.733514 -0.234132

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06', '2013-01-07', '2013-01-08',
#                '2013-01-09', '2013-01-10', '2013-01-11', '2013-01-12',
#                '2013-01-13', '2013-01-14', '2013-01-15', '2013-01-16',
#                '2013-01-17', '2013-01-18', '2013-01-19', '2013-01-20'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.to_numpy()
# Out:
# array([[-0.34406125, -0.76025543,  0.77342875,  2.05747047],
#        [-1.2239315 , -1.05723846, -1.13820152,  0.07308976],
#        [ 0.27469853, -1.62481495, -1.08288739,  0.59306174],
#        [ 0.55138398, -0.58006598,  1.61421873, -0.40964532],
#        [ 1.25720512,  0.35876752, -2.551062  , -1.84104708],
#        [ 0.6118644 , -0.30120962, -0.55314055,  2.28250898],
#        [ 2.25803706,  0.6425367 , -0.2361681 , -1.48563667],
# 2013-01-15 -0.100896  1.182679  1.356832  0.219337
# 2013-01-16  0.353042  0.343070  0.863696 -1.367427
# 2013-01-17  0.443104 -0.476834  0.057122  0.345396
# ...

# %%
df["B"]
# Out:
# 2013-01-01   -0.760255
# 2013-01-02   -1.057238
# 2013-01-03   -1.624815
# 2013-01-04   -0.580066
# 2013-01-05    0.358768
# 2013-01-06   -0.301210
# 2013-01-07    0.642537
# 2013-01-08   -0.503774
# 2013-01-09    0.172734
# 2013-01-10    1.000938
# 2013-01-11    0.283592
# 2013-01-12   -1.551997
# 2013-01-13   -0.153085
# 2013-01-14    0.890055
# 2013-01-15    1.182679
# 2013-01-16    0.343070
# 2013-01-17   -0.476834
# 2013-01-18   -0.934476
# 2013-01-19    0.654585
# 2013-01-20   -0.770276
# Freq: D, Name: B, dtype: float64

# %%
df[0:2]
# Out:
#                    A         B         C        D
# 2013-01-01 -0.344061 -0.760255  0.773429  2.05747
# 2013-01-02 -1.223932 -1.057238 -1.138202  0.07309

# %%
df[0:]
# Out:
#                    A         B         C         D
# 2013-01-01 -0.344061 -0.760255  0.773429  2.057470
# 2013-01-02 -1.223932 -1.057238 -1.138202  0.073090
# 2013-01-03  0.274699 -1.624815 -1.082887  0.593062
# 2013-01-04  0.551384 -0.580066  1.614219 -0.409645
# 2013-01-05  1.257205  0.358768 -2.551062 -1.841047
# 2013-01-06  0.611864 -0.301210 -0.553141  2.282509
# 2013-01-07  2.258037  0.642537 -0.236168 -1.485637
# 2013-01-08 -0.729323 -0.503774 -0.491015 -1.265484
# 2013-01-09  0.992290  0.172734  1.092731 -1.529189
# 2013-01-10 -0.635694  1.000938  0.647804  0.594693
# 2013-01-11 -0.184144  0.283592 -0.881308 -0.245401
# 2013-01-12 -0.610837 -1.551997  2.057645 -0.820753
# 2013-01-13 -0.234148 -0.153085  0.331640  0.582614
# 2013-01-14  2.139897  0.890055 -0.076824  0.020482
# 2013-01-15 -0.100896  1.182679  1.356832  0.219337
# 2013-01-16  0.353042  0.343070  0.863696 -1.367427
# 2013-01-17  0.443104 -0.476834  0.057122  0.345396
# ...

# %%
df[1:10]
# Out:
#                    A         B         C         D
# 2013-01-02 -1.223932 -1.057238 -1.138202  0.073090
# 2013-01-03  0.274699 -1.624815 -1.082887  0.593062
# 2013-01-04  0.551384 -0.580066  1.614219 -0.409645
# 2013-01-05  1.257205  0.358768 -2.551062 -1.841047
# 2013-01-06  0.611864 -0.301210 -0.553141  2.282509
# 2013-01-07  2.258037  0.642537 -0.236168 -1.485637
# 2013-01-08 -0.729323 -0.503774 -0.491015 -1.265484
# 2013-01-09  0.992290  0.172734  1.092731 -1.529189
# 2013-01-10 -0.635694  1.000938  0.647804  0.594693

# %%
df.loc[dates[0]]
# Out:
# A   -0.344061
# B   -0.760255
# C    0.773429
# D    2.057470
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[dates[8]]
# Out:
# A    0.992290
# B    0.172734
# C    1.092731
# D   -1.529189
# Name: 2013-01-09 00:00:00, dtype: float64

# %%
df.loc[:,["A","B"]]
# Out:
#                    A         B
# 2013-01-01 -0.344061 -0.760255
# 2013-01-02 -1.223932 -1.057238
# 2013-01-03  0.274699 -1.624815
# 2013-01-04  0.551384 -0.580066
# 2013-01-05  1.257205  0.358768
# 2013-01-06  0.611864 -0.301210
# 2013-01-07  2.258037  0.642537
# 2013-01-08 -0.729323 -0.503774
# 2013-01-09  0.992290  0.172734
# 2013-01-10 -0.635694  1.000938
# 2013-01-11 -0.184144  0.283592
# 2013-01-12 -0.610837 -1.551997
# 2013-01-13 -0.234148 -0.153085
# 2013-01-14  2.139897  0.890055
# 2013-01-15 -0.100896  1.182679
# 2013-01-16  0.353042  0.343070
# 2013-01-17  0.443104 -0.476834
# 2013-01-18  0.132675 -0.934476
# 2013-01-19 -0.600790  0.654585
# 2013-01-20  0.831436 -0.770276

# %%
df.loc[:,["A","B"]]
# Out:
#                    A         B
# 2013-01-01 -0.344061 -0.760255
# 2013-01-02 -1.223932 -1.057238
# 2013-01-03  0.274699 -1.624815
# 2013-01-04  0.551384 -0.580066
# 2013-01-05  1.257205  0.358768
# 2013-01-06  0.611864 -0.301210
# 2013-01-07  2.258037  0.642537
# 2013-01-08 -0.729323 -0.503774
# 2013-01-09  0.992290  0.172734
# 2013-01-10 -0.635694  1.000938
# 2013-01-11 -0.184144  0.283592
# 2013-01-12 -0.610837 -1.551997
# 2013-01-13 -0.234148 -0.153085
# 2013-01-14  2.139897  0.890055
# 2013-01-15 -0.100896  1.182679
# 2013-01-16  0.353042  0.343070
# 2013-01-17  0.443104 -0.476834
# 2013-01-18  0.132675 -0.934476
# 2013-01-19 -0.600790  0.654585
# 2013-01-20  0.831436 -0.770276

# %%
df.loc["20130102":"20130104",["A","B"]]
# Out:
#                    A         B
# 2013-01-02 -1.223932 -1.057238
# 2013-01-03  0.274699 -1.624815
# 2013-01-04  0.551384 -0.580066

# %%
df.loc["20130102",["A","B"]]
# Out:
# A   -1.223932
# B   -1.057238
# Name: 2013-01-02 00:00:00, dtype: float64

# %%
df.at[dates[0],"A"]
# Out:
# np.float64(-0.34406125232204554)

# %%
df.iloc[3]
# Out:
# A    0.551384
# B   -0.580066
# C    1.614219
# D   -0.409645
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:10]
# Out:
#                    A         B         C         D
# 2013-01-04  0.551384 -0.580066  1.614219 -0.409645
# 2013-01-05  1.257205  0.358768 -2.551062 -1.841047
# 2013-01-06  0.611864 -0.301210 -0.553141  2.282509
# 2013-01-07  2.258037  0.642537 -0.236168 -1.485637
# 2013-01-08 -0.729323 -0.503774 -0.491015 -1.265484
# 2013-01-09  0.992290  0.172734  1.092731 -1.529189
# 2013-01-10 -0.635694  1.000938  0.647804  0.594693

# %%
df.iloc[0:5,0:3]# rows and column
# Out:
#                    A         B         C
# 2013-01-01 -0.344061 -0.760255  0.773429
# 2013-01-02 -1.223932 -1.057238 -1.138202
# 2013-01-03  0.274699 -1.624815 -1.082887
# 2013-01-04  0.551384 -0.580066  1.614219
# 2013-01-05  1.257205  0.358768 -2.551062

# %%
df.iloc[: ,0:1]
# Out:
#                    A
# 2013-01-01 -0.344061
# 2013-01-02 -1.223932
# 2013-01-03  0.274699
# 2013-01-04  0.551384
# 2013-01-05  1.257205
# 2013-01-06  0.611864
# 2013-01-07  2.258037
# 2013-01-08 -0.729323
# 2013-01-09  0.992290
# 2013-01-10 -0.635694
# 2013-01-11 -0.184144
# 2013-01-12 -0.610837
# 2013-01-13 -0.234148
# 2013-01-14  2.139897
# 2013-01-15 -0.100896
# 2013-01-16  0.353042
# 2013-01-17  0.443104
# 2013-01-18  0.132675
# 2013-01-19 -0.600790
# 2013-01-20  0.831436

# %%
df[df["A"]>0]
# Out:
#                    A         B         C         D
# 2013-01-03  0.274699 -1.624815 -1.082887  0.593062
# 2013-01-04  0.551384 -0.580066  1.614219 -0.409645
# 2013-01-05  1.257205  0.358768 -2.551062 -1.841047
# 2013-01-06  0.611864 -0.301210 -0.553141  2.282509
# 2013-01-07  2.258037  0.642537 -0.236168 -1.485637
# 2013-01-09  0.992290  0.172734  1.092731 -1.529189
# 2013-01-14  2.139897  0.890055 -0.076824  0.020482
# 2013-01-16  0.353042  0.343070  0.863696 -1.367427
# 2013-01-17  0.443104 -0.476834  0.057122  0.345396
# 2013-01-18  0.132675 -0.934476 -1.129261 -0.254599
# 2013-01-20  0.831436 -0.770276 -1.733514 -0.234132

# %%
df[df>0]
# Out:
#                    A         B         C         D
# 2013-01-01       NaN       NaN  0.773429  2.057470
# 2013-01-02       NaN       NaN       NaN  0.073090
# 2013-01-03  0.274699       NaN       NaN  0.593062
# 2013-01-04  0.551384       NaN  1.614219       NaN
# 2013-01-05  1.257205  0.358768       NaN       NaN
# 2013-01-06  0.611864       NaN       NaN  2.282509
# 2013-01-07  2.258037  0.642537       NaN       NaN
# 2013-01-08       NaN       NaN       NaN       NaN
# 2013-01-09  0.992290  0.172734  1.092731       NaN
# 2013-01-10       NaN  1.000938  0.647804  0.594693
# 2013-01-11       NaN  0.283592       NaN       NaN
# 2013-01-12       NaN       NaN  2.057645       NaN
# 2013-01-13       NaN       NaN  0.331640  0.582614
# 2013-01-14  2.139897  0.890055       NaN  0.020482
# 2013-01-15       NaN  1.182679  1.356832  0.219337
# 2013-01-16  0.353042  0.343070  0.863696       NaN
# 2013-01-17  0.443104       NaN  0.057122  0.345396
# ...

# %%
df2 = df.copy()
df2["E"]=["one","two","three","four","five","six","one","two","three","four","five","six","one","two","three","four","five","six","one","two"]
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01 -0.344061 -0.760255  0.773429  2.057470    one
# 2013-01-02 -1.223932 -1.057238 -1.138202  0.073090    two
# 2013-01-03  0.274699 -1.624815 -1.082887  0.593062  three
# 2013-01-04  0.551384 -0.580066  1.614219 -0.409645   four
# 2013-01-05  1.257205  0.358768 -2.551062 -1.841047   five
# 2013-01-06  0.611864 -0.301210 -0.553141  2.282509    six
# 2013-01-07  2.258037  0.642537 -0.236168 -1.485637    one
# 2013-01-08 -0.729323 -0.503774 -0.491015 -1.265484    two
# 2013-01-09  0.992290  0.172734  1.092731 -1.529189  three
# 2013-01-10 -0.635694  1.000938  0.647804  0.594693   four
# 2013-01-11 -0.184144  0.283592 -0.881308 -0.245401   five
# 2013-01-12 -0.610837 -1.551997  2.057645 -0.820753    six
# 2013-01-13 -0.234148 -0.153085  0.331640  0.582614    one
# 2013-01-14  2.139897  0.890055 -0.076824  0.020482    two
# 2013-01-15 -0.100896  1.182679  1.356832  0.219337  three
# ...

# %%
df["mean"]=[1.2,1.3,1.4,1.6,2.3, 1.2,1.3,1.4,1.6,2.3, 1.2,1.3,1.4,1.6,2.3, 1.2,1.3,1.4,1.6,2.3,]
df
# Out:
#                    A         B         C         D  mean
# 2013-01-01 -0.344061 -0.760255  0.773429  2.057470   1.2
# 2013-01-02 -1.223932 -1.057238 -1.138202  0.073090   1.3
# 2013-01-03  0.274699 -1.624815 -1.082887  0.593062   1.4
# 2013-01-04  0.551384 -0.580066  1.614219 -0.409645   1.6
# 2013-01-05  1.257205  0.358768 -2.551062 -1.841047   2.3
# 2013-01-06  0.611864 -0.301210 -0.553141  2.282509   1.2
# 2013-01-07  2.258037  0.642537 -0.236168 -1.485637   1.3
# 2013-01-08 -0.729323 -0.503774 -0.491015 -1.265484   1.4
# 2013-01-09  0.992290  0.172734  1.092731 -1.529189   1.6
# 2013-01-10 -0.635694  1.000938  0.647804  0.594693   2.3
# 2013-01-11 -0.184144  0.283592 -0.881308 -0.245401   1.2
# 2013-01-12 -0.610837 -1.551997  2.057645 -0.820753   1.3
# 2013-01-13 -0.234148 -0.153085  0.331640  0.582614   1.4
# 2013-01-14  2.139897  0.890055 -0.076824  0.020482   1.6
# 2013-01-15 -0.100896  1.182679  1.356832  0.219337   2.3
# ...

# %%
df=df.iloc[ : ,0:4]
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.344061 -0.760255  0.773429  2.057470
# 2013-01-02 -1.223932 -1.057238 -1.138202  0.073090
# 2013-01-03  0.274699 -1.624815 -1.082887  0.593062
# 2013-01-04  0.551384 -0.580066  1.614219 -0.409645
# 2013-01-05  1.257205  0.358768 -2.551062 -1.841047
# 2013-01-06  0.611864 -0.301210 -0.553141  2.282509
# 2013-01-07  2.258037  0.642537 -0.236168 -1.485637
# 2013-01-08 -0.729323 -0.503774 -0.491015 -1.265484
# 2013-01-09  0.992290  0.172734  1.092731 -1.529189
# 2013-01-10 -0.635694  1.000938  0.647804  0.594693
# 2013-01-11 -0.184144  0.283592 -0.881308 -0.245401
# 2013-01-12 -0.610837 -1.551997  2.057645 -0.820753
# 2013-01-13 -0.234148 -0.153085  0.331640  0.582614
# 2013-01-14  2.139897  0.890055 -0.076824  0.020482
# 2013-01-15 -0.100896  1.182679  1.356832  0.219337
# 2013-01-16  0.353042  0.343070  0.863696 -1.367427
# 2013-01-17  0.443104 -0.476834  0.057122  0.345396
# ...

# %% [markdown]
# FAOSTAT
