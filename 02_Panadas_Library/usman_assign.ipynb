# %%
# import libraries
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
#import data from file
baba_usman = pd.read_csv("usman_assign2.csv")
baba_usman


sns.set_theme(style="ticks", color_codes=True)

p = sns.boxplot(x="Year", hue="Element", data=baba_usman)
plt.show()

# %%
# saving datafram into csv file
baba_usman.to_csv('baba_usman.csv')

# %%
# basic statistics or summary
baba_usman.describe()
# Out:
#        Area Code  Element Code  Item Code    Year Code         Year  \
# count       58.0     58.000000       58.0    58.000000    58.000000
# mean       165.0    556.000000     3010.0  2004.000000  2004.000000
# std          0.0      5.043669        0.0     8.439672     8.439672
# min        165.0    551.000000     3010.0  1990.000000  1990.000000
# 25%        165.0    551.000000     3010.0  1997.000000  1997.000000
# 50%        165.0    556.000000     3010.0  2004.000000  2004.000000
# 75%        165.0    561.000000     3010.0  2011.000000  2011.000000
# max        165.0    561.000000     3010.0  2018.000000  2018.000000
#
#                Value
# count      58.000000
# mean    76031.216966
# std     28181.561500
# min     32923.693000
# 25%     51276.889250
# 50%     74192.675500
# 75%     99409.902500
# max    127183.388000

# %%
baba_usman.head(5)
# Out:
#   Domain Code             Domain  Area Code      Area  Element Code  \
# 0          OA  Annual population        165  Pakistan           551
# 1          OA  Annual population        165  Pakistan           561
# 2          OA  Annual population        165  Pakistan           561
# 3          OA  Annual population        165  Pakistan           551
# 4          OA  Annual population        165  Pakistan           551
#
#             Element  Item Code                       Item  Year Code  Year  \
# 0  Rural population       3010  Population - Est. & Proj.       1990  1990
# 1  Urban population       3010  Population - Est. & Proj.       1990  1990
# 2  Urban population       3010  Population - Est. & Proj.       1991  1991
# 3  Rural population       3010  Population - Est. & Proj.       1991  1991
# 4  Rural population       3010  Population - Est. & Proj.       1992  1992
#
#            Unit      Value Flag                Flag Description  \
# ...

# %%
# droping few columns and make a new dataset
baba_usman.drop(['Domain Code','Flag'],axis=1)
# Out:
#                Domain  Area Code      Area  Element Code           Element  \
# 0   Annual population        165  Pakistan           551  Rural population
# 1   Annual population        165  Pakistan           561  Urban population
# 2   Annual population        165  Pakistan           561  Urban population
# 3   Annual population        165  Pakistan           551  Rural population
# 4   Annual population        165  Pakistan           551  Rural population
# 5   Annual population        165  Pakistan           561  Urban population
# 6   Annual population        165  Pakistan           561  Urban population
# 7   Annual population        165  Pakistan           551  Rural population
# 8   Annual population        165  Pakistan           551  Rural population
# 9   Annual population        165  Pakistan           561  Urban population
# 10  Annual population        165  Pakistan           561  Urban population
# ...

# %%
baba_usman.drop(['Domain Code','Flag'],axis=1).head()
# Out:
#               Domain  Area Code      Area  Element Code           Element  \
# 0  Annual population        165  Pakistan           551  Rural population
# 1  Annual population        165  Pakistan           561  Urban population
# 2  Annual population        165  Pakistan           561  Urban population
# 3  Annual population        165  Pakistan           551  Rural population
# 4  Annual population        165  Pakistan           551  Rural population
#
#    Item Code                       Item  Year Code  Year          Unit  \
# 0       3010  Population - Est. & Proj.       1990  1990  1000 persons
# 1       3010  Population - Est. & Proj.       1990  1990  1000 persons
# 2       3010  Population - Est. & Proj.       1991  1991  1000 persons
# 3       3010  Population - Est. & Proj.       1991  1991  1000 persons
# 4       3010  Population - Est. & Proj.       1992  1992  1000 persons
#
#        Value                Flag Description  \
# ...

# %%
baba_usman.mean()
# Out:
# C:\Users\alias\AppData\Local\Temp/ipykernel_8436/2256491601.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   baba_usman.mean()
# Area Code         165.000000
# Element Code      556.000000
# Item Code        3010.000000
# Year Code        2004.000000
# Year             2004.000000
# Value           76031.216966
# dtype: float64

# %%
baba_usman.groupby(['Element','Year']).mean()
# Out:
#                        Area Code  Element Code  Item Code  Year Code  \
# Element          Year
# Rural population 1990      165.0         551.0     3010.0     1990.0
#                  1991      165.0         551.0     3010.0     1991.0
#                  1992      165.0         551.0     3010.0     1992.0
#                  1993      165.0         551.0     3010.0     1993.0
#                  1994      165.0         551.0     3010.0     1994.0
#                  1995      165.0         551.0     3010.0     1995.0
#                  1996      165.0         551.0     3010.0     1996.0
#                  1997      165.0         551.0     3010.0     1997.0
#                  1998      165.0         551.0     3010.0     1998.0
#                  1999      165.0         551.0     3010.0     1999.0
#                  2000      165.0         551.0     3010.0     2000.0
#                  2001      165.0         551.0     3010.0     2001.0
# ...

# %%
baba_usman.groupby(['Element']).mean()
# Out:
#                   Area Code  Element Code  Item Code  Year Code    Year  \
# Element
# Rural population      165.0         551.0     3010.0     2004.0  2004.0
# Urban population      165.0         561.0     3010.0     2004.0  2004.0
#
#                           Value
# Element
# Rural population  100277.637207
# Urban population   51784.796724
